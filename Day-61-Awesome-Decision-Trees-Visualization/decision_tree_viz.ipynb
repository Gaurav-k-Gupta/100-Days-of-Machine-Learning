# %%
import pandas as pd
import numpy as np

# %%
# !pip install dtreeviz
# Out:
# Collecting dtreeviz
#   Downloading dtreeviz-2.2.2-py3-none-any.whl.metadata (2.4 kB)
# Collecting graphviz>=0.9 (from dtreeviz)
#   Downloading graphviz-0.20.3-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: pandas in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from dtreeviz) (2.2.3)
# Requirement already satisfied: numpy in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from dtreeviz) (2.0.0)
# Requirement already satisfied: scikit-learn in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from dtreeviz) (1.6.0)
# Requirement already satisfied: matplotlib in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from dtreeviz) (3.9.0)
# Collecting colour (from dtreeviz)
#   Downloading colour-0.1.5-py2.py3-none-any.whl.metadata (18 kB)
# Collecting pytest (from dtreeviz)
#   Downloading pytest-8.3.5-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->dtreeviz) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->dtreeviz) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->dtreeviz) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->dtreeviz) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->dtreeviz) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->dtreeviz) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->dtreeviz) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->dtreeviz) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from pandas->dtreeviz) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from pandas->dtreeviz) (2024.2)
# Requirement already satisfied: colorama in c:\users\gaurav gupta\appdata\roaming\python\python312\site-packages (from pytest->dtreeviz) (0.4.6)
# Collecting iniconfig (from pytest->dtreeviz)
#   Downloading iniconfig-2.0.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting pluggy<2,>=1.5 (from pytest->dtreeviz)
#   Downloading pluggy-1.5.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn->dtreeviz) (1.15.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn->dtreeviz) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn->dtreeviz) (3.5.0)
# Requirement already satisfied: six>=1.5 in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib->dtreeviz) (1.16.0)
# Downloading dtreeviz-2.2.2-py3-none-any.whl (91 kB)
# Downloading graphviz-0.20.3-py3-none-any.whl (47 kB)
# Downloading colour-0.1.5-py2.py3-none-any.whl (23 kB)
# Downloading pytest-8.3.5-py3-none-any.whl (343 kB)
# Downloading pluggy-1.5.0-py3-none-any.whl (20 kB)
# Downloading iniconfig-2.0.0-py3-none-any.whl (5.9 kB)
# Installing collected packages: colour, pluggy, iniconfig, graphviz, pytest, dtreeviz
# Successfully installed colour-0.1.5 dtreeviz-2.2.2 graphviz-0.20.3 iniconfig-2.0.0 pluggy-1.5.0 pytest-8.3.5
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from dtreeviz.trees import *
from sklearn.datasets import *
from IPython.display import Image , display_svg , SVG
import graphviz.backend as be

# %%
dt = tree.DecisionTreeClassifier(max_depth=2)
iris = load_iris()
X_train = iris.data
Y_train = iris.target

# %%
dt.fit(X_train , Y_train)
# Out:
# DecisionTreeClassifier(max_depth=2)

# %%
from sklearn.tree import plot_tree
plot_tree(dt)
# Out:
# [Text(0.4, 0.8333333333333334, 'x[3] <= 0.8\ngini = 0.667\nsamples = 150\nvalue = [50, 50, 50]'),
#  Text(0.2, 0.5, 'gini = 0.0\nsamples = 50\nvalue = [50, 0, 0]'),
#  Text(0.30000000000000004, 0.6666666666666667, 'True  '),
#  Text(0.6, 0.5, 'x[3] <= 1.75\ngini = 0.5\nsamples = 100\nvalue = [0, 50, 50]'),
#  Text(0.5, 0.6666666666666667, '  False'),
#  Text(0.4, 0.16666666666666666, 'gini = 0.168\nsamples = 54\nvalue = [0, 49, 5]'),
#  Text(0.8, 0.16666666666666666, 'gini = 0.043\nsamples = 46\nvalue = [0, 1, 45]')]

# %%
# !pip install dtreeviz
# Out:
# Requirement already satisfied: dtreeviz in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (2.2.2)
# Requirement already satisfied: graphviz>=0.9 in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from dtreeviz) (0.20.3)
# Requirement already satisfied: pandas in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from dtreeviz) (2.2.3)
# Requirement already satisfied: numpy in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from dtreeviz) (2.0.0)
# Requirement already satisfied: scikit-learn in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from dtreeviz) (1.6.0)
# Requirement already satisfied: matplotlib in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from dtreeviz) (3.9.0)
# Requirement already satisfied: colour in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from dtreeviz) (0.1.5)
# Requirement already satisfied: pytest in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from dtreeviz) (8.3.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->dtreeviz) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->dtreeviz) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->dtreeviz) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->dtreeviz) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->dtreeviz) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->dtreeviz) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->dtreeviz) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->dtreeviz) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from pandas->dtreeviz) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from pandas->dtreeviz) (2024.2)
# Requirement already satisfied: colorama in c:\users\gaurav gupta\appdata\roaming\python\python312\site-packages (from pytest->dtreeviz) (0.4.6)
# Requirement already satisfied: iniconfig in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from pytest->dtreeviz) (2.0.0)
# Requirement already satisfied: pluggy<2,>=1.5 in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from pytest->dtreeviz) (1.5.0)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn->dtreeviz) (1.15.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn->dtreeviz) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn->dtreeviz) (3.5.0)
# Requirement already satisfied: six>=1.5 in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib->dtreeviz) (1.16.0)
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import dtreeviz

# %%
X_train.shape , Y_train.shape
# Out:
# ((150, 4), (150,))

# %%
X_train = np.array(X_train)
Y_train = np.array(Y_train)

# %%
# !pip install --upgrade dtreeviz
# Out:
# Requirement already satisfied: dtreeviz in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (2.2.2)
# Requirement already satisfied: graphviz>=0.9 in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from dtreeviz) (0.20.3)
# Requirement already satisfied: pandas in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from dtreeviz) (2.2.3)
# Requirement already satisfied: numpy in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from dtreeviz) (2.0.0)
# Requirement already satisfied: scikit-learn in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from dtreeviz) (1.6.0)
# Requirement already satisfied: matplotlib in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from dtreeviz) (3.9.0)
# Requirement already satisfied: colour in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from dtreeviz) (0.1.5)
# Requirement already satisfied: pytest in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from dtreeviz) (8.3.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->dtreeviz) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->dtreeviz) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->dtreeviz) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->dtreeviz) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->dtreeviz) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->dtreeviz) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->dtreeviz) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->dtreeviz) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from pandas->dtreeviz) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from pandas->dtreeviz) (2024.2)
# Requirement already satisfied: colorama in c:\users\gaurav gupta\appdata\roaming\python\python312\site-packages (from pytest->dtreeviz) (0.4.6)
# Requirement already satisfied: iniconfig in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from pytest->dtreeviz) (2.0.0)
# Requirement already satisfied: pluggy<2,>=1.5 in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from pytest->dtreeviz) (1.5.0)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn->dtreeviz) (1.15.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn->dtreeviz) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn->dtreeviz) (3.5.0)
# Requirement already satisfied: six>=1.5 in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib->dtreeviz) (1.16.0)
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
viz_model = dtreeviz.model(
    dt,
    X_train=X_train,
    y_train=Y_train,
    feature_names=iris.feature_names,
    class_names=["setosa" , "versicolor" , "virginica"]
)

# %%
viz_model.view(scale=2)
