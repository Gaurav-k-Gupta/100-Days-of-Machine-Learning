# %% [markdown]
# <h1>Working with JSON</h1>

# %%
import pandas as pd
pd.read_json('sample_data/anscombe.json')
# Out:
#    Series   X      Y
# 0       I  10   8.04
# 1       I   8   6.95
# 2       I  13   7.58
# 3       I   9   8.81
# 4       I  11   8.33
# 5       I  14   9.96
# 6       I   6   7.24
# 7       I   4   4.26
# 8       I  12  10.84
# 9       I   7   4.81
# 10      I   5   5.68
# 11     II  10   9.14
# 12     II   8   8.14
# 13     II  13   8.74
# 14     II   9   8.77
# 15     II  11   9.26
# 16     II  14   8.10
# 17     II   6   6.13
# 18     II   4   3.10
# 19     II  12   9.13
# 20     II   7   7.26
# 21     II   5   4.74
# 22    III  10   7.46
# 23    III   8   6.77
# 24    III  13  12.74
# 25    III   9   7.11
# 26    III  11   7.81
# 27    III  14   8.84
# 28    III   6   6.08
# 29    III   4   5.39
# 30    III  12   8.15
# 31    III   7   6.42
# 32    III   5   5.73
# 33     IV   8   6.58
# 34     IV   8   5.76
# 35     IV   8   7.71
# 36     IV   8   8.84
# 37     IV   8   8.47
# 38     IV   8   7.04
# 39     IV   8   5.25
# 40     IV  19  12.50
# 41     IV   8   5.56
# ...

# %% [markdown]
# <h1>Downloading a dataset from kaggle (Json format) using kaggle library</h1>

# %%
# !pip install kaggle
# !kaggle datasets download -d rtatman/iris-dataset-json-version -p sample_data
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/rtatman/iris-dataset-json-version
# License(s): unknown
# ...
#   0% 0.00/1.31k [00:00<?, ?B/s]
# 100% 1.31k/1.31k [00:00<00:00, 2.65MB/s]

# %% [markdown]
# <h1>Unzip the dataset</h1>

# %%
# !unzip sample_data/iris-dataset-json-version.zip
# Out:
# Archive:  sample_data/iris-dataset-json-version.zip
#   inflating: iris.json

# %%
pd.read_json('iris.json')
# Out:
#      sepalLength  sepalWidth  petalLength  petalWidth    species
# 0            5.1         3.5          1.4         0.2     setosa
# 1            4.9         3.0          1.4         0.2     setosa
# 2            4.7         3.2          1.3         0.2     setosa
# 3            4.6         3.1          1.5         0.2     setosa
# 4            5.0         3.6          1.4         0.2     setosa
# ..           ...         ...          ...         ...        ...
# 145          6.7         3.0          5.2         2.3  virginica
# 146          6.3         2.5          5.0         1.9  virginica
# 147          6.5         3.0          5.2         2.0  virginica
# 148          6.2         3.4          5.4         2.3  virginica
# 149          5.9         3.0          5.1         1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# <h1>Fetching json data through a url</h1>

# %%
pd.read_json('https://v6.exchangerate-api.com/v6/6a74ebf48c3d24849bde56a1/latest/INR')
# Out:
#       result                          documentation  \
# INR  success  https://www.exchangerate-api.com/docs
# AED  success  https://www.exchangerate-api.com/docs
# AFN  success  https://www.exchangerate-api.com/docs
# ALL  success  https://www.exchangerate-api.com/docs
# AMD  success  https://www.exchangerate-api.com/docs
# ..       ...                                    ...
# XPF  success  https://www.exchangerate-api.com/docs
# YER  success  https://www.exchangerate-api.com/docs
# ZAR  success  https://www.exchangerate-api.com/docs
# ZMW  success  https://www.exchangerate-api.com/docs
# ZWL  success  https://www.exchangerate-api.com/docs
#
#                                terms_of_use  time_last_update_unix  \
# INR  https://www.exchangerate-api.com/terms             1734825601
# AED  https://www.exchangerate-api.com/terms             1734825601
# AFN  https://www.exchangerate-api.com/terms             1734825601
# ...

# %% [markdown]
# <h1>Working With SQL</h1>

# %% [markdown]
# <h1>Installing Mysql connector</h1>

# %%
# !pip install mysql.connector
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.9/11.9 MB 65.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for mysql.connector: filename=mysql_connector-2.2.9-cp310-cp310-linux_x86_64.whl size=247948 sha256=fb665bbfb27e248156020cf2a9069aa82855a52894a1bd7183881fd3dfd3e0c9
#   Stored in directory: /root/.cache/pip/wheels/76/48/9b/da67ff1a18fe8e9d428f9b1a177716d4a7d363d2bbe83bf6cf
# Successfully built mysql.connector
# ...

# %% [markdown]
# <h2> Import mysql connector and connect it to the database, we will get a connection string</h2>

# %%
import mysql.connector

# %%
conn = mysql.connector.connect(host='localhost', user='root' , password='' , database='world')

# %%
# It reads the sql database and bring tables from there.....we have to pass the connection object in this function!
pd.read_sql_query("SELECT * FROM city" , conn)
