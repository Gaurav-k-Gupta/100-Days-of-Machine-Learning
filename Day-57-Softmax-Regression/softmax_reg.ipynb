# %% [markdown]
# <h1>Softmax Regression</h1>

# %%
import numpy as np
import pandas as pd

# %%
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix , accuracy_score
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset('iris')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
encoder = LabelEncoder()
df['species'] = encoder.fit_transform(df['species'])

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0

# %%
df = df[['sepal_length' , 'petal_length' , 'species']]

# %%
df.head()
# Out:
#    sepal_length  petal_length  species
# 0           5.1           1.4        0
# 1           4.9           1.4        0
# 2           4.7           1.3        0
# 3           4.6           1.5        0
# 4           5.0           1.4        0

# %%
X = df.iloc[:,0:2]
Y = df.iloc[:,-1]

# %%
X_train,X_test,Y_train,Y_test = train_test_split( X , Y , test_size=0.2 , random_state=21)

# %%
clf = LogisticRegression(multi_class='multinomial')
clf.fit(X_train , Y_train)
# Out:
# c:\Users\gaurav gupta\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# LogisticRegression(multi_class='multinomial')

# %%
Y_pred = clf.predict(X_test)

# %%
accuracy_score(Y_test , Y_pred)
# Out:
# 0.9

# %%
pd.DataFrame(confusion_matrix(Y_test , Y_pred))
# Out:
#     0   1  2
# 0  11   0  0
# 1   0  10  2
# 2   0   1  6

# %%
#prediction
query = np.array([[3.4 , 2.7]])
clf.predict_proba(query) #softmax output
# Out:
# c:\Users\gaurav gupta\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([[7.97016306e-01, 2.02748051e-01, 2.35643675e-04]])

# %%
clf.predict(query)
# Out:
# c:\Users\gaurav gupta\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0])

# %%
# !pip install mlxtend
# Out:
# Collecting mlxtend
#   Downloading mlxtend-0.23.4-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: scipy>=1.2.1 in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from mlxtend) (1.15.0)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from mlxtend) (2.0.0)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from mlxtend) (2.2.3)
# Requirement already satisfied: scikit-learn>=1.3.1 in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from mlxtend) (1.6.0)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from mlxtend) (3.9.0)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from mlxtend) (1.4.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from pandas>=0.24.2->mlxtend) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from pandas>=0.24.2->mlxtend) (2024.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn>=1.3.1->mlxtend) (3.5.0)
# Requirement already satisfied: six>=1.5 in c:\users\gaurav gupta\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)
# Downloading mlxtend-0.23.4-py3-none-any.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB ? eta -:--:--
#    --------------- ------------------------ 0.5/1.4 MB 188.6 kB/s eta 0:00:05
#    --------------- ------------------------ 0.5/1.4 MB 188.6 kB/s eta 0:00:05
#    --------------- ------------------------ 0.5/1.4 MB 188.6 kB/s eta 0:00:05
#    --------------- ------------------------ 0.5/1.4 MB 188.6 kB/s eta 0:00:05
#    --------------- ------------------------ 0.5/1.4 MB 188.6 kB/s eta 0:00:05
#    --------------- ------------------------ 0.5/1.4 MB 188.6 kB/s eta 0:00:05
#    --------------- ------------------------ 0.5/1.4 MB 188.6 kB/s eta 0:00:05
#    --------------- ------------------------ 0.5/1.4 MB 188.6 kB/s eta 0:00:05
#    --------------- ------------------------ 0.5/1.4 MB 188.6 kB/s eta 0:00:05
#    --------------- ------------------------ 0.5/1.4 MB 188.6 kB/s eta 0:00:05
#    --------------- ------------------------ 0.5/1.4 MB 188.6 kB/s eta 0:00:05
#    --------------- ------------------------ 0.5/1.4 MB 188.6 kB/s eta 0:00:05
#    --------------- ------------------------ 0.5/1.4 MB 188.6 kB/s eta 0:00:05
#    --------------- ------------------------ 0.5/1.4 MB 188.6 kB/s eta 0:00:05
#    --------------- ------------------------ 0.5/1.4 MB 188.6 kB/s eta 0:00:05
#    --------------- ------------------------ 0.5/1.4 MB 188.6 kB/s eta 0:00:05
#    --------------- ------------------------ 0.5/1.4 MB 188.6 kB/s eta 0:00:05
#    --------------- ------------------------ 0.5/1.4 MB 188.6 kB/s eta 0:00:05
#    --------------- ------------------------ 0.5/1.4 MB 188.6 kB/s eta 0:00:05
#    --------------- ------------------------ 0.5/1.4 MB 188.6 kB/s eta 0:00:05
#    --------------- ------------------------ 0.5/1.4 MB 188.6 kB/s eta 0:00:05
#    --------------- ------------------------ 0.5/1.4 MB 188.6 kB/s eta 0:00:05
#    --------------- ------------------------ 0.5/1.4 MB 188.6 kB/s eta 0:00:05
#    --------------- ------------------------ 0.5/1.4 MB 188.6 kB/s eta 0:00:05
#    --------------- ------------------------ 0.5/1.4 MB 188.6 kB/s eta 0:00:05
#    --------------- ------------------------ 0.5/1.4 MB 188.6 kB/s eta 0:00:05
#    --------------- ------------------------ 0.5/1.4 MB 188.6 kB/s eta 0:00:05
#    --------------- ------------------------ 0.5/1.4 MB 188.6 kB/s eta 0:00:05
#    --------------- ------------------------ 0.5/1.4 MB 188.6 kB/s eta 0:00:05
#    ----------------------- ---------------- 0.8/1.4 MB 71.1 kB/s eta 0:00:08
#    ----------------------- ---------------- 0.8/1.4 MB 71.1 kB/s eta 0:00:08
#    ----------------------- ---------------- 0.8/1.4 MB 71.1 kB/s eta 0:00:08
#    ----------------------- ---------------- 0.8/1.4 MB 71.1 kB/s eta 0:00:08
#    ----------------------- ---------------- 0.8/1.4 MB 71.1 kB/s eta 0:00:08
#    ----------------------- ---------------- 0.8/1.4 MB 71.1 kB/s eta 0:00:08
#    ----------------------- ---------------- 0.8/1.4 MB 71.1 kB/s eta 0:00:08
#    ----------------------- ---------------- 0.8/1.4 MB 71.1 kB/s eta 0:00:08
#    ----------------------- ---------------- 0.8/1.4 MB 71.1 kB/s eta 0:00:08
#    ----------------------- ---------------- 0.8/1.4 MB 71.1 kB/s eta 0:00:08
#    ----------------------- ---------------- 0.8/1.4 MB 71.1 kB/s eta 0:00:08
#    ----------------------- ---------------- 0.8/1.4 MB 71.1 kB/s eta 0:00:08
#    ----------------------- ---------------- 0.8/1.4 MB 71.1 kB/s eta 0:00:08
#    ----------------------- ---------------- 0.8/1.4 MB 71.1 kB/s eta 0:00:08
#    ----------------------- ---------------- 0.8/1.4 MB 71.1 kB/s eta 0:00:08
#    ----------------------- ---------------- 0.8/1.4 MB 71.1 kB/s eta 0:00:08
#    ----------------------- ---------------- 0.8/1.4 MB 71.1 kB/s eta 0:00:08
#    ----------------------- ---------------- 0.8/1.4 MB 71.1 kB/s eta 0:00:08
#    ----------------------- ---------------- 0.8/1.4 MB 71.1 kB/s eta 0:00:08
#    ----------------------- ---------------- 0.8/1.4 MB 71.1 kB/s eta 0:00:08
#    ----------------------- ---------------- 0.8/1.4 MB 71.1 kB/s eta 0:00:08
#    ----------------------- ---------------- 0.8/1.4 MB 71.1 kB/s eta 0:00:08
#    ----------------------- ---------------- 0.8/1.4 MB 71.1 kB/s eta 0:00:08
#    ----------------------- ---------------- 0.8/1.4 MB 71.1 kB/s eta 0:00:08
#    ----------------------- ---------------- 0.8/1.4 MB 71.1 kB/s eta 0:00:08
#    ----------------------- ---------------- 0.8/1.4 MB 71.1 kB/s eta 0:00:08
#    ----------------------- ---------------- 0.8/1.4 MB 71.1 kB/s eta 0:00:08
#    ----------------------- ---------------- 0.8/1.4 MB 71.1 kB/s eta 0:00:08
#    ----------------------- ---------------- 0.8/1.4 MB 71.1 kB/s eta 0:00:08
#    ----------------------- ---------------- 0.8/1.4 MB 71.1 kB/s eta 0:00:08
#    ----------------------- ---------------- 0.8/1.4 MB 71.1 kB/s eta 0:00:08
#    ------------------------------- -------- 1.0/1.4 MB 56.6 kB/s eta 0:00:06
#    ------------------------------- -------- 1.0/1.4 MB 56.6 kB/s eta 0:00:06
#    ------------------------------- -------- 1.0/1.4 MB 56.6 kB/s eta 0:00:06
#    ------------------------------- -------- 1.0/1.4 MB 56.6 kB/s eta 0:00:06
#    ------------------------------- -------- 1.0/1.4 MB 56.6 kB/s eta 0:00:06
#    ------------------------------- -------- 1.0/1.4 MB 56.6 kB/s eta 0:00:06
#    ------------------------------- -------- 1.0/1.4 MB 56.6 kB/s eta 0:00:06
#    -------------------------------------- - 1.3/1.4 MB 67.4 kB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 69.1 kB/s eta 0:00:00
# Installing collected packages: mlxtend
# Successfully installed mlxtend-0.23.4
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(X.values , Y.values , clf , legend=2)
plt.xlabel('sepal length [cm]')
plt.ylabel('petal length [cm]')
plt.title('softmax on iris dataset')
# Out:
# c:\Users\gaurav gupta\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# Text(0.5, 1.0, 'softmax on iris dataset')
