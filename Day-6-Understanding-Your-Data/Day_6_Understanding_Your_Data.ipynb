# %% [markdown]
# <h1>Understanding your data</h1>

# %%
import pandas as pd

# %% [markdown]
# <h1>Downloading a dataset from kaggle</h1>

# %%
# !pip install kaggle
# !kaggle datasets download -d hetbabariya/imdb-movies-data-collection-5000-records -p sample_data
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/hetbabariya/imdb-movies-data-collection-5000-records
# License(s): CC0-1.0
# ...
#   0% 0.00/934k [00:00<?, ?B/s]
# 100% 934k/934k [00:00<00:00, 86.5MB/s]

# %%
# !unzip sample_data/imdb-movies-data-collection-5000-records.zip
# Out:
# Archive:  sample_data/imdb-movies-data-collection-5000-records.zip
#   inflating: IMDB_Movies_Dataset.csv

# %%
df = pd.read_csv('movies_imdb.csv')

# %% [markdown]
# <h1>1. How big is the data</h1>

# %%
df.shape
# Out:
# (4989, 13)

# %% [markdown]
# <h1>2. How does the data look like?</h1>

# %%
# df.head()
df.sample(5)
# Out:
#       Unnamed: 0                                     Title  Average Rating  \
# 3402         411                       Pride and Prejudice             7.4
# 3134         143                              Galaxy Quest             7.4
# 3532          42                      Les choses de la vie             7.4
# 539           39                                   Ben-Hur             8.1
# 429          429  Rascal Does Not Dream of a Dreaming Girl             8.2
#
#                Director                                             Writer  \
# 3402  Robert Z. Leonard            Aldous Huxley, Jane Murfin, Jane Austen
# 3134       Dean Parisot                        David Howard, Robert Gordon
# 3532      Claude Sautet  Sandro Continenza, Jean-Loup Dabadie, Paul Gui...
# 539       William Wyler              Lew Wallace, Karl Tunberg, Gore Vidal
# 429        Sôichi Masui                Hajime Kamoshida, Masahiro Yokotani
#
# ...

# %% [markdown]
# <h1>3. What is the datatype of cols?</h1>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4989 entries, 0 to 4988
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         4989 non-null   int64
#  1   Title              4989 non-null   object
#  2   Average Rating     4989 non-null   float64
#  3   Director           4989 non-null   object
#  4   Writer             4988 non-null   object
#  5   Metascore          3055 non-null   float64
#  6   Cast               4982 non-null   object
#  7   Release Date       4989 non-null   object
#  8   Country of Origin  4986 non-null   object
#  9   Languages          4968 non-null   object
#  10  Budget             2651 non-null   object
#  11  Worldwide Gross    3895 non-null   object
#  12  Runtime            4989 non-null   object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 506.8+ KB

# %% [markdown]
# <h1>4. Are there any missing values?</h1>

# %%
df.isnull().sum()
# Out:
# Unnamed: 0              0
# Title                   0
# Average Rating          0
# Director                0
# Writer                  1
# Metascore            1934
# Cast                    7
# Release Date            0
# Country of Origin       3
# Languages              21
# Budget               2338
# Worldwide Gross      1094
# Runtime                 0
# dtype: int64

# %% [markdown]
# <h1>5. How does the data look mathematically?</h1>

# %%
df.describe()
# Out:
#         Unnamed: 0  Average Rating    Metascore
# count  4989.000000     4989.000000  3055.000000
# mean    248.951493        7.632892    74.684452
# std     144.036753        0.365243    12.298911
# min       0.000000        7.200000    25.000000
# 25%     124.000000        7.300000    67.000000
# 50%     249.000000        7.600000    76.000000
# 75%     374.000000        7.800000    84.000000
# max     499.000000        9.300000   100.000000

# %% [markdown]
# <h1>6. Are there any duplicate values?</h1>

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# <h1>7. How is the correlation between cols</h1>

# %%
numeric_df = df.select_dtypes(include=['number'])
numeric_df.corr()
# Out:
#                 Unnamed: 0  Average Rating  Metascore
# Unnamed: 0        1.000000       -0.117564  -0.013052
# Average Rating   -0.117564        1.000000   0.342531
# Metascore        -0.013052        0.342531   1.000000
